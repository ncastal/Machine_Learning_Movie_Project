# %%
from numpy.random import seed
seed(1)
from tensorflow import random
random.set_seed(1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
import pandas as pd

# %%
df = pd.read_csv('final_df.csv')
df = df.drop(columns = ['Unnamed: 0'])
df.head()
# Out:
#                             title  year        country language  duration  \
# 0                          Psycho  1960            USA  English       109
# 1                       Spartacus  1960            USA  English       197
# 2           Swiss Family Robinson  1960            USA  English       126
# 3  One Hundred and One Dalmatians  1961            USA  English        79
# 4         Une femme est une femme  1961  France, Italy   French        85
#
#                           genre                        director  \
# 0     Horror, Mystery, Thriller                Alfred Hitchcock
# 1   Adventure, Biography, Drama                 Stanley Kubrick
# 2             Adventure, Family                     Ken Annakin
# 3  Animation, Adventure, Comedy  Clyde Geronimi, Hamilton Luske
# 4        Comedy, Drama, Romance                 Jean-Luc Godard
#
#               production_company  \
# 0            Shamley Productions
# 1              Bryna Productions
# 2        Walt Disney Productions
# 3        Walt Disney Productions
# 4  Euro International Film (EIA)
#
#                                          description      budget  ...  \
# 0  A Phoenix secretary embezzles forty thousand d...    $ 806947  ...
# 1  The slave Spartacus leads a violent revolt aga...  $ 12000000  ...
# 2  A Swiss family must survive being shipwrecked ...   $ 5000000  ...
# 3  When a litter of Dalmatian puppies are abducte...   $ 4000000  ...
# 4  A French striptease artist is desperate to bec...    $ 160000  ...
#
#   country_1 country_2  country_3  budget_USD             actor_1  listing_1  \
# 0       USA       NaN        NaN    806947.0     Anthony Perkins          D
# 1       USA       NaN        NaN  12000000.0        Kirk Douglas          D
# 2       USA       NaN        NaN   5000000.0          John Mills          D
# 3       USA       NaN        NaN   4000000.0          Rod Taylor          D
# 4    France     Italy        NaN    160000.0  Jean-Claude Brialy          D
#
#             actor_2  listing_2             actor_3  listing_3
# 0        Vera Miles          D          John Gavin          D
# 1  Laurence Olivier          D        Jean Simmons          D
# 2   Dorothy McGuire          D     James MacArthur          D
# 3   J. Pat O'Malley          D    Betty Lou Gerson          D
# 4       Anna Karina          D  Jean-Paul Belmondo          D
#
# [5 rows x 47 columns]

# %%
df2 = df.dropna()
df2
# Out:
#                                     title  year  \
# 13                              Cleopatra  1963
# 25                         Doctor Zhivago  1965
# 56    Willy Wonka & the Chocolate Factory  1971
# 126                              Superman  1978
# 162                           Superman II  1980
# ...                                   ...   ...
# 4109       Godzilla: King of the Monsters  2019
# 4110                                Dumbo  2019
# 4121                Terminator: Dark Fate  2019
# 4139                         Cold Pursuit  2019
# 4140            Pokémon Detective Pikachu  2019
#
#                                        country  \
# 13                        Switzerland, UK, USA
# 25               USA, Italy, UK, Liechtenstein
# 56             USA, East Germany, West Germany
# 126               USA, UK, Canada, Switzerland
# 162                            USA, UK, Canada
# ...                                        ...
# 4109                        Japan, Canada, USA
# 4110                USA, UK, Australia, Canada
# 4121                       USA, Spain, Hungary
# 4139  UK, Norway, Canada, USA, France, Germany
# 4140                    USA, Japan, UK, Canada
#
#                                  language  duration  \
# 13                                English       192
# 25               English, Russian, French       197
# 56       English, French, German, Italian       100
# 126                               English       143
# 162              English, French, Russian       127
# ...                                   ...       ...
# 4109  English, Japanese, Chinese, Spanish       132
# 4110                      English, French       112
# 4121                     English, Spanish       128
# 4139        English, Vietnamese, Shoshoni       119
# 4140                              English       104
#
#                            genre                        director  \
# 13     Biography, Drama, History            Joseph L. Mankiewicz
# 25           Drama, Romance, War                      David Lean
# 56      Family, Fantasy, Musical                      Mel Stuart
# 126     Action, Adventure, Drama                  Richard Donner
# 162    Action, Adventure, Sci-Fi  Richard Lester, Richard Donner
# ...                          ...                             ...
# 4109  Action, Adventure, Fantasy               Michael Dougherty
# 4110  Adventure, Family, Fantasy                      Tim Burton
# 4121   Action, Adventure, Sci-Fi                      Tim Miller
# 4139        Action, Crime, Drama              Hans Petter Moland
# 4140   Action, Adventure, Comedy                   Rob Letterman
#
#              production_company  \
# 13        Twentieth Century Fox
# 25    Metro-Goldwyn-Mayer (MGM)
# 56         Wolper Pictures Ltd.
# 126              Dovemead Films
# 162              Dovemead Films
# ...                         ...
# 4109               Warner Bros.
# 4110       Walt Disney Pictures
# 4121         Paramount Pictures
# 4139                StudioCanal
# 4140               Warner Bros.
#
#                                             description       budget  ...  \
# 13    Queen Cleopatra VII of Egypt experiences both ...   $ 44000000  ...
# 25    The life of a Russian physician and poet who, ...   $ 11000000  ...
# 56    A poor but hopeful boy seeks one of the five c...    $ 3000000  ...
# 126   An alien orphan is sent from his dying planet ...   $ 55000000  ...
# 162   Superman agrees to sacrifice his powers to sta...   $ 54000000  ...
# ...                                                 ...          ...  ...
# 4109  The crypto-zoological agency Monarch faces off...  $ 170000000  ...
# 4110  A young elephant, whose oversized ears enable ...  $ 170000000  ...
# 4121  Sarah Connor and a hybrid cyborg human must pr...  $ 185000000  ...
# 4139  A grieving snowplow driver seeks out revenge a...   $ 60000000  ...
# 4140  In a world where people collect Pokémon to do ...  $ 150000000  ...
#
#         country_1      country_2      country_3   budget_USD  \
# 13    Switzerland             UK            USA   44000000.0
# 25            USA          Italy             UK   11000000.0
# 56            USA   East Germany   West Germany    3000000.0
# 126           USA             UK         Canada   55000000.0
# 162           USA             UK         Canada   54000000.0
# ...           ...            ...            ...          ...
# 4109        Japan         Canada            USA  170000000.0
# 4110          USA             UK      Australia  170000000.0
# 4121          USA          Spain        Hungary  185000000.0
# 4139           UK         Norway         Canada   60000000.0
# 4140          USA          Japan             UK  150000000.0
#
#                actor_1  listing_1                actor_2  listing_2  \
# 13    Elizabeth Taylor          D         Richard Burton          D
# 25         Omar Sharif          D         Julie Christie          D
# 56         Gene Wilder          D         Jack Albertson          D
# 126      Marlon Brando          D           Gene Hackman          C
# 162       Gene Hackman          C      Christopher Reeve          D
# ...                ...        ...                    ...        ...
# 4109     Kyle Chandler          D           Vera Farmiga          C
# 4110     Colin Farrell          A         Michael Keaton          A
# 4121    Linda Hamilton          D  Arnold Schwarzenegger          A
# 4139       Liam Neeson          A             Laura Dern          D
# 4140     Ryan Reynolds          A          Justice Smith          D
#
#                  actor_3  listing_3
# 13          Rex Harrison          D
# 25     Geraldine Chaplin          D
# 56          Peter Ostrum          D
# 126    Christopher Reeve          D
# 162           Ned Beatty          D
# ...                  ...        ...
# 4109  Millie Bobby Brown          D
# 4110        Danny DeVito          B
# 4121     Mackenzie Davis          D
# 4139  Micheál Richardson          D
# 4140      Kathryn Newton          D
#
# [485 rows x 47 columns]

# %%
y = df2['overall_eval']
target_names = ['good', 'bad']

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
X = df2[['budget_USD', 'usa_gross_income','duration','genre_1', 'genre_2', 'genre_3', 'country_1','country_2', 'country_3','director','production_company','listing_1', 'listing_2', 'listing_3','votes', 'male_avg_rating', 'female_avg_rating', 
         'reviews_from_users','reviews_from_critics','avg_rating_<18yrs', 'avg_rating_18-30yrs', 'avg_rating_30-45yrs', 'avg_rating_>45yrs']].apply(LabelEncoder().fit_transform)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from tensorflow.keras.utils import to_categorical

# %%
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense

# model = Sequential()
# model.add(Dense(units=6, activation='relu', input_dim=2))
# model.add(Dense(units=2, activation='softmax'))

# %%
# model.compile(optimizer='adam',
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])

# %%
# model.fit(
#     X_train_scaled,
#     y_train_categorical,
#     epochs=100,
#     shuffle=True,
#     verbose=2
# )

# %%
deep_model = Sequential()
deep_model.add(Dense(units=6, activation='relu', input_dim=2))
deep_model.add(Dense(units=6, activation='relu'))
deep_model.add(Dense(units=2, activation='softmax'))

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-df77224d076e> in <module>
#       8     epochs=100,
#       9     shuffle=True,
# ---> 10     verbose=2
#      11 )
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     222           validation_data=validation_data,
#     223           validation_steps=validation_steps,
# --> 224           distribution_strategy=strategy)
#     225
#     226       total_samples = _get_total_number_of_samples(training_data_adapter)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in _process_training_inputs(model, x, y, batch_size, epochs, sample_weights, class_weights, steps_per_epoch, validation_split, validation_data, validation_steps, shuffle, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     545         max_queue_size=max_queue_size,
#     546         workers=workers,
# --> 547         use_multiprocessing=use_multiprocessing)
#     548     val_adapter = None
#     549     if validation_data:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in _process_inputs(model, x, y, batch_size, epochs, sample_weights, class_weights, shuffle, steps, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     592         batch_size=batch_size,
#     593         check_steps=False,
# --> 594         steps=steps)
#     595   adapter = adapter_cls(
#     596       x,
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2470           feed_input_shapes,
#    2471           check_batch_axis=False,  # Don't enforce the batch size.
# -> 2472           exception_prefix='input')
#    2473
#    2474     # Get typespecs for the input data and sanitize it if necessary.
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     572                              ': expected ' + names[i] + ' to have shape ' +
#     573                              str(shape) + ' but got array with shape ' +
# --> 574                              str(data_shape))
#     575   return data
#     576
#
# ValueError: Error when checking input: expected dense_7_input to have shape (2,) but got array with shape (23,)
